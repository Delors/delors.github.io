# %% [markdown]
# $X_{n+1} = (aX_n + c)\; mod\; m$

# %%
def lcg(x0, a,c,m, count):
    print(f"seed = {x0}, a = {a}, c = {c}, m = {m}")
    i = 0
    xn = x0
    while i < count:
        print(f"{xn}, ", end="")
        xn = (a * xn + c ) % m
        
        i += 1

# %%
print()
lcg(1234,8,8,256,100)

print()
lcg(1234,-8,8,256,100)

print()
lcg(1234,-11,7,113,100)

print()
lcg(1234,11551,127,11927,100)
# Out:
# seed=1234, a=8, c=8, m=256
# 1234, 152, 200, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72, 72,
# seed=1234, a=-8, c=8, m=256
# 1234, 120, 72, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200, 200,
# seed=1234, a=-11, c=7, m=113
# 1234, 106, 84, 100, 37, 52, 0, 7, 43, 99, 48, 44, 88, 56, 69, 39, 30, 16, 57, 58, 47, 55, 80, 31, 5, 65, 83, 111, 29, 27, 49, 33, 96, 81, 20, 13, 90, 34, 85, 89, 45, 77, 64, 94, 103, 4, 76, 75, 86, 78, 53, 102, 15, 68, 50, 22, 104, 106, 84, 100, 37, 52, 0, 7, 43, 99, 48, 44, 88, 56, 69, 39, 30, 16, 57, 58, 47, 55, 80, 31, 5, 65, 83, 111, 29, 27, 49, 33, 96, 81, 20, 13, 90, 34, 85, 89, 45, 77, 64, 94,
# seed=1234, a=11551, c=127, m=11927
# 1234, 1296, 1838, 805, 7549, 329, 7620, 9414, 2782, 3671, 3363, 11828, 1570, 6157, 10860, 7728, 4587, 4830, 8878, 1559, 10293, 6234, 5762, 4329, 6422, 6636, 9661, 5326, 1287, 5222, 4610, 8109, 4455, 6754, 1074, 1821, 7197, 1484, 2712, 6137, 6453, 6907, 3181, 8698, 9604, 2904, 5507, 4793, 10863, 6600, 11270, 8619, 3527, 9799, 1146, 10530, 611, 8931, 5485, 1138, 1611, 2668, 10754, 11803, 10970, 2149, 3139, 636, 11458, 9493, 8859, 8703, 7724, 6091, 11822, 3826, 4718, 3282, 6503, 34, 11197, 286, 11861, 1089, 8108, 4831, 8502, 11738, 11556, 8426, 4533, 1280, 7854, 4919, 11195, 1038, 3430, 10490, 3724, 7289,
